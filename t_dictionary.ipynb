# %%
import pandas as pd
from IPython.display import display
import sqlite3

# %%
# Conexão database SQLite

consqlite = sqlite3.connect('C:/Users/matheus.candido/sqlite3/exploracao_petroleo_brasil.db', timeout=10)

# %%
# Display dicionário de dados

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    dictionary_db = pd.read_sql_query("SELECT * FROM T_DICTIONARY WHERE TABELA NOT LIKE 'T_DATAHUB'", consqlite)
    display(dictionary_db)
# Out:
#                TABELA                       CAMPO          TIPO  \
# 0             D_BACIA                       BACIA   VARCHAR(50)
# 1             D_BACIA                   COD_BACIA   VARCHAR(10)
# 2             D_CAMPO                       CAMPO   VARCHAR(50)
# 3             D_CAMPO                   COD_CAMPO   VARCHAR(20)
# 4         D_CATEGORIA                   CATEGORIA   VARCHAR(50)
# 5         D_CATEGORIA               COD_CATEGORIA           INT
# 6            D_ESTADO                  COD_ESTADO   VARCHAR(10)
# 7            D_ESTADO                 ESTADO_NOME   VARCHAR(50)
# 8     D_POCO_OPERADOR           COD_CADASTRO_POCO   VARCHAR(50)
# 9     D_POCO_OPERADOR                    COD_POCO   VARCHAR(20)
# 10    D_POCO_OPERADOR                    OPERADOR   VARCHAR(20)
# 11    D_POCO_OPERADOR               POCO_OPERADOR   VARCHAR(50)
# 12  D_RECLASSIFICACAO         COD_RECLASSIFICACAO   VARCHAR(20)
# 13  D_RECLASSIFICACAO             RECLASSIFICACAO  VARCHAR(100)
# ...
